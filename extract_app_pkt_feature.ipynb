# %%
import numpy as np
import pandas as pd
from importlib import reload

# %%
# define constants
TRACE_FILE_NAME = 'data/tencent_game_na.pcapng' # replace with your raw trace .pcapng/.pcap file name
TRACE_TCP_PACKET_FEATURE_FILE_NAME = 'data/tencent_game_na_tcp_pkt.csv' # replace with your favorite tcp packet feature .csv file name
TRACE_UDP_PACKET_FEATURE_FILE_NAME = 'data/tencent_game_na_udp_pkt.csv' # replace with your favorite udp packet feature .csv file name
TRACE_PACKET_FEATURE_FILE_NAME = 'data/tencent_game_na_pkt.csv' # replace with your favorite packet feature .csv file name
# LOCAL_IP = '172.16.26.207' # your local ip

# %% [markdown]
# ## Extract TCP packets

# %%
# convert raw trace to readable udp and tcp packet feature csv file
from python import packet_feature
reload(packet_feature)
# %time packet_feature.tcp_generate(TRACE_FILE_NAME,TRACE_TCP_PACKET_FEATURE_FILE_NAME)
# Out:
# Conversion done
# CPU times: user 2.6 ms, sys: 6.17 ms, total: 8.77 ms
# Wall time: 9.21 s

# %%
# read in packet feature csv file and do some transformation
import ipaddress
tcp_pkt_feature_df = pd.read_csv(TRACE_TCP_PACKET_FEATURE_FILE_NAME)
filterer = tcp_pkt_feature_df.apply(lambda row:(not pd.isnull(row['ip.src']) and ipaddress.IPv4Address(row['ip.src']).is_global) or (not pd.isnull(row['ip.dst']) and ipaddress.IPv4Address(row['ip.dst']).is_global),axis=1)
tcp_pkt_feature_df = tcp_pkt_feature_df[filterer]
record_num = tcp_pkt_feature_df.shape[0]
tcp_pkt_feature_df['remote_ip'] = tcp_pkt_feature_df.apply(lambda row:row['ip.dst'] if ipaddress.IPv4Address(row['ip.dst']).is_global else row['ip.src'],axis=1) if record_num > 0 else None
tcp_pkt_feature_df['remote_ip2num'] = tcp_pkt_feature_df.apply(lambda row:int(ipaddress.IPv4Address(row['remote_ip'])),axis=1) if record_num > 0 else None
tcp_pkt_feature_df['protocol'] = 'tcp' if record_num > 0 else None
tcp_pkt_feature_df['is_tcp'] = 1 if record_num > 0 else None
tcp_pkt_feature_df['is_udp'] = 0 if record_num > 0 else None
tcp_pkt_feature_df.rename(columns={'tcp.len':'pkt_len'},inplace=True)

# %%
# view the shape of the dataset: (number of records, number of features)
tcp_pkt_feature_df.shape
# Out:
# (52802, 17)

# %%
# view the data types for each feature
tcp_pkt_feature_df.dtypes
# Out:
# ip.src                  object
# ip.dst                  object
# tcp.srcport              int64
# tcp.dstport              int64
# pkt_len                  int64
# frame.time_relative    float64
# tcp.seq                  int64
# tcp.ack                  int64
# tcp.flags.ack            int64
# tcp.flags.syn            int64
# tcp.flags.fin            int64
# tcp.stream               int64
# remote_ip               object
# remote_ip2num            int64
# protocol                object
# is_tcp                   int64
# is_udp                   int64
# dtype: object

# %%
# view the statistical features of each numerical feature
tcp_pkt_feature_df.describe()
# Out:
#         tcp.srcport   tcp.dstport       pkt_len  frame.time_relative  \
# count  52802.000000  52802.000000  52802.000000         52802.000000
# mean   17299.196621  26272.557384    762.424075            65.674473
# std    20903.021846  20906.418760    668.026356           184.472434
# min       80.000000     80.000000      0.000000             0.000000
# 25%      443.000000    443.000000      0.000000            22.638198
# 50%      443.000000  36444.000000   1368.000000            24.453401
# 75%    40288.000000  45140.000000   1368.000000            27.152311
# max    63704.000000  63704.000000   1380.000000          1338.640061
#
#             tcp.seq       tcp.ack  tcp.flags.ack  tcp.flags.syn  \
# count  5.280200e+04  5.280200e+04   52802.000000   52802.000000
# mean   3.093605e+05  1.769940e+05       0.990644       0.007140
# std    4.038899e+05  3.381204e+05       0.096272       0.084196
# min    0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    7.490000e+02  5.080000e+02       1.000000       0.000000
# 50%    1.038070e+05  9.900000e+02       1.000000       0.000000
# 75%    5.381900e+05  2.005992e+05       1.000000       0.000000
# max    1.883614e+06  1.883638e+06       1.000000       1.000000
#
#        tcp.flags.fin    tcp.stream  remote_ip2num   is_tcp   is_udp
# count   52802.000000  52802.000000   5.280200e+04  52802.0  52802.0
# mean        0.005738     74.305443   1.530230e+09      1.0      0.0
# std         0.075535     28.333318   8.704069e+08      0.0      0.0
# min         0.000000      0.000000   2.880297e+08      1.0      0.0
# 25%         0.000000     58.000000   4.004113e+08      1.0      0.0
# 50%         0.000000     68.000000   2.163119e+09      1.0      0.0
# 75%         0.000000     79.000000   2.163119e+09      1.0      0.0
# max         1.000000    232.000000   3.736744e+09      1.0      0.0

# %%
# view the first 5 records
tcp_pkt_feature_df.head()
# Out:
#             ip.src           ip.dst  tcp.srcport  tcp.dstport  pkt_len  \
# 0  128.238.147.112   17.248.135.181        63660          443     1368
# 1  128.238.147.112   17.248.135.181        63660          443      101
# 2  128.238.147.112   17.248.135.181        63660          443     1368
# 3   17.248.135.181  128.238.147.112          443        63660        0
# 4  128.238.147.112   17.248.135.181        63660          443      824
#
#    frame.time_relative  tcp.seq  tcp.ack  tcp.flags.ack  tcp.flags.syn  \
# 0             0.000000        1        1              1              0
# 1             0.000001     1369        1              1              0
# 2             0.000274     1470        1              1              0
# 3             0.001493        1     1470              1              0
# 4             0.001524     2838        1              1              0
#
#    tcp.flags.fin  tcp.stream        remote_ip  remote_ip2num protocol  is_tcp  \
# 0              0           0   17.248.135.181      301500341      tcp       1
# 1              0           0   17.248.135.181      301500341      tcp       1
# 2              0           0   17.248.135.181      301500341      tcp       1
# 3              0           0  128.238.147.112     2163118960      tcp       1
# 4              0           0   17.248.135.181      301500341      tcp       1
#
#    is_udp
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## Extract UDP packets

# %%
# convert raw trace to readable udp and tcp packet feature csv file
from python import packet_feature
reload(packet_feature)
# %time packet_feature.udp_generate(TRACE_FILE_NAME,TRACE_UDP_PACKET_FEATURE_FILE_NAME,True)
# Out:
# Conversion done
# No error
# CPU times: user 4.27 ms, sys: 5.45 ms, total: 9.73 ms
# Wall time: 7.6 s

# %%
udp_pkt_feature_df = pd.read_csv(TRACE_UDP_PACKET_FEATURE_FILE_NAME)
udp_pkt_feature_df
# Out:
#                 ip.src           ip.dst  udp.srcport  udp.dstport  udp.length  \
# 0        128.238.147.3        224.0.0.2         1985         1985          28
# 1        128.238.147.2        224.0.0.2         1985         1985          28
# 2      128.238.147.145  128.238.147.255        37481         1534          16
# 3        128.238.147.3        224.0.0.2         1985         1985          28
# 4        128.238.147.2        224.0.0.2         1985         1985          28
# 5      128.238.147.137  255.255.255.255        17500        17500         152
# 6      128.238.147.137  128.238.147.255        17500        17500         152
# 7      128.238.147.112     128.238.1.69        64703           53          40
# 8      128.238.147.112     128.238.1.69        51917           53          45
# 9      128.238.147.112     128.238.1.69        61129           53          49
# 10        128.238.1.69  128.238.147.112           53        64703         296
# 11        128.238.1.69  128.238.147.112           53        51917          61
# 12     128.238.147.112     128.238.1.69        61106           53          45
# 13        128.238.1.69  128.238.147.112           53        61106         287
# 14     128.238.147.112     128.238.1.69        64050           53          60
# 15        128.238.1.69  128.238.147.112           53        64050         302
# 16     128.238.147.112     128.238.1.69        56627           53          43
# 17        128.238.1.69  128.238.147.112           53        56627          91
# 18        128.238.1.69  128.238.147.112           53        61129         143
# 19     128.238.147.112     128.238.1.69        62417           53          44
# 20        128.238.1.69  128.238.147.112           53        62417         286
# 21     128.238.147.112     128.238.1.69        63535           53          42
# 22        128.238.1.69  128.238.147.112           53        63535          82
# 23     128.238.147.112     128.238.1.69        50358           53          47
# 24        128.238.1.69  128.238.147.112           53        50358         188
# 25     128.238.147.112     128.238.1.69        59184           53          39
# 26        128.238.1.69  128.238.147.112           53        59184          55
# 27     128.238.147.112     128.238.1.69        53177           53          38
# 28        128.238.1.69  128.238.147.112           53        53177         265
# 29       128.238.147.3        224.0.0.2         1985         1985          28
# ...                ...              ...          ...          ...         ...
# 43889    128.238.147.2        224.0.0.2         1985         1985          28
# 43890    128.238.147.2        224.0.0.2         1985         1985          28
# 43891    128.238.147.3        224.0.0.2         1985         1985          28
# 43892  128.238.147.206  255.255.255.255        17500        17500         259
# 43893  128.238.147.206  128.238.147.255        17500        17500         259
# 43894    128.238.147.3        224.0.0.2         1985         1985          28
# 43895    128.238.147.2        224.0.0.2         1985         1985          28
# 43896  128.238.147.145  128.238.147.255        37481         1534          16
# 43897    128.238.147.2        224.0.0.2         1985         1985          28
# 43898    128.238.147.3        224.0.0.2         1985         1985          28
# 43899    128.238.147.3        224.0.0.2         1985         1985          28
# 43900    128.238.147.2        224.0.0.2         1985         1985          28
# 43901    128.238.147.3        224.0.0.2         1985         1985          28
# 43902    128.238.147.2        224.0.0.2         1985         1985          28
# 43903              NaN              NaN          546          547          86
# 43904  128.238.147.137  255.255.255.255        17500        17500         152
# 43905  128.238.147.137  128.238.147.255        17500        17500         152
# 43906  128.238.147.132  255.255.255.255        17500        17500         152
# 43907  128.238.147.132  128.238.147.255        17500        17500         152
# 43908    128.238.147.3        224.0.0.2         1985         1985          28
# 43909    128.238.147.2        224.0.0.2         1985         1985          28
# 43910  128.238.147.137  239.255.255.250        59509         1900         182
# 43911    128.238.147.3        224.0.0.2         1985         1985          28
# 43912    128.238.147.2        224.0.0.2         1985         1985          28
# 43913  128.238.147.145  128.238.147.255        37481         1534          16
# 43914    128.238.147.3        224.0.0.2         1985         1985          28
# 43915    128.238.147.2        224.0.0.2         1985         1985          28
# 43916  128.238.147.137  239.255.255.250        59509         1900         182
# 43917    128.238.147.3        224.0.0.2         1985         1985          28
# 43918    128.238.147.2        224.0.0.2         1985         1985          28
#
#        frame.time_relative  udp.stream
# 0                 0.097179           0
# 1                 0.100842           1
# 2                 0.574101           2
# 3                 3.096920           0
# 4                 3.101557           1
# 5                 4.347565           3
# 6                 4.347699           4
# 7                 4.791367           5
# 8                 4.791480           6
# 9                 4.791661           7
# 10                4.792323           5
# 11                4.792326           6
# 12                4.795225           8
# 13                4.795922           8
# 14                4.800879           9
# 15                4.820251           9
# 16                5.003409          10
# 17                5.005099          10
# 18                5.236065           7
# 19                5.376681          11
# 20                5.394867          11
# 21                5.399147          12
# 22                5.399779          12
# 23                5.411735          13
# 24                5.437308          13
# 25                5.530586          14
# 26                5.531204          14
# 27                5.737444          15
# 28                5.738257          15
# 29                6.094969           0
# ...                    ...         ...
# 43889          1311.682683           1
# 43890          1314.666986           1
# 43891          1314.673919           0
# 43892          1317.257268          37
# 43893          1317.257931          38
# 43894          1317.671774           0
# 43895          1317.680354           1
# 43896          1320.653838           2
# 43897          1320.667069           1
# 43898          1320.677737           0
# 43899          1323.673765           0
# 43900          1323.686028           1
# 43901          1326.673770           0
# 43902          1326.679827           1
# 43903          1327.165246          36
# 43904          1328.236320           3
# 43905          1328.236474           4
# 43906          1329.157869          22
# 43907          1329.158016          23
# 43908          1329.673747           0
# 43909          1329.679694           1
# 43910          1331.645886         214
# 43911          1332.673742           0
# 43912          1332.679790           1
# 43913          1335.654766           2
# 43914          1335.675881           0
# 43915          1335.680030           1
# 43916          1336.578973         214
# 43917          1338.675751           0
# 43918          1338.676886           1
#
# [43919 rows x 7 columns]

# %%
# read in packet feature csv file and do some transformation
import ipaddress
def filter_illegal(row):
    try:
        ipaddress.IPv4Address(row['ip.src'])
        ipaddress.IPv4Address(row['ip.dst'])
        return (not pd.isnull(row['ip.src']) and ipaddress.IPv4Address(row['ip.src']).is_global) or (not pd.isnull(row['ip.dst']) and ipaddress.IPv4Address(row['ip.dst']).is_global)
    except ValueError as e:
        print(e)
        return False                                                                                
                                                                                                
udp_pkt_feature_df = pd.read_csv(TRACE_UDP_PACKET_FEATURE_FILE_NAME)
filterer = udp_pkt_feature_df.apply(filter_illegal,axis=1)
udp_pkt_feature_df = udp_pkt_feature_df[filterer]
record_num = udp_pkt_feature_df.shape[0]
udp_pkt_feature_df['remote_ip'] = udp_pkt_feature_df.apply(lambda row:row['ip.dst'] if ipaddress.IPv4Address(row['ip.dst']).is_global else row['ip.src'],axis=1) if record_num > 0 else None
udp_pkt_feature_df['remote_ip2num'] = udp_pkt_feature_df.apply(lambda row:int(ipaddress.IPv4Address(row['remote_ip'])),axis=1) if record_num > 0 else None
udp_pkt_feature_df['protocol'] = 'udp' if record_num > 0 else None
udp_pkt_feature_df['is_tcp'] = 0 if record_num > 0 else None
udp_pkt_feature_df['is_udp'] = 1 if record_num > 0 else None
udp_pkt_feature_df.rename(columns={'udp.length':'pkt_len'},inplace=True)
# Out:
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in 'nan'
# Expected 4 octets in '128.238.147.112,169.47.201.155'
# Expected 4 octets in 'nan'

# %%
# view the shape of the dataset: (number of records, number of features)
udp_pkt_feature_df.shape
# Out:
# (43819, 12)

# %%
# view the data types for each feature
udp_pkt_feature_df.dtypes
# Out:
# ip.src                  object
# ip.dst                  object
# udp.srcport              int64
# udp.dstport              int64
# pkt_len                  int64
# frame.time_relative    float64
# udp.stream               int64
# remote_ip               object
# remote_ip2num            int64
# protocol                object
# is_tcp                   int64
# is_udp                   int64
# dtype: object

# %%
# view the statistical features of each numerical feature
udp_pkt_feature_df.describe()
# Out:
#         udp.srcport   udp.dstport       pkt_len  frame.time_relative  \
# count  43819.000000  43819.000000  43819.000000         43819.000000
# mean   25193.044866  22211.606997    173.944271           716.771043
# std    17599.801570  17467.249729    115.121193           338.969400
# min       53.000000     53.000000     16.000000             0.097179
# 25%     6651.000000   6651.000000    102.000000           429.984005
# 50%    41764.000000   6651.000000    102.000000           724.518986
# 75%    41764.000000  41764.000000    294.000000          1002.336581
# max    65437.000000  65437.000000    532.000000          1338.676886
#
#          udp.stream  remote_ip2num   is_tcp   is_udp
# count  43819.000000   4.381900e+04  43819.0  43819.0
# mean      83.376252   2.550868e+09      0.0      1.0
# std       15.466526   3.987631e+08      0.0      0.0
# min        0.000000   3.017985e+08      0.0      1.0
# 25%       85.000000   2.163119e+09      0.0      1.0
# 50%       85.000000   2.838481e+09      0.0      1.0
# 75%       85.000000   2.838481e+09      0.0      1.0
# max      214.000000   4.026532e+09      0.0      1.0

# %%
# view the first 5 records
udp_pkt_feature_df.head()
# Out:
#             ip.src           ip.dst  udp.srcport  udp.dstport  pkt_len  \
# 0    128.238.147.3        224.0.0.2         1985         1985       28
# 1    128.238.147.2        224.0.0.2         1985         1985       28
# 2  128.238.147.145  128.238.147.255        37481         1534       16
# 3    128.238.147.3        224.0.0.2         1985         1985       28
# 4    128.238.147.2        224.0.0.2         1985         1985       28
#
#    frame.time_relative  udp.stream        remote_ip  remote_ip2num protocol  \
# 0             0.097179           0        224.0.0.2     3758096386      udp
# 1             0.100842           1        224.0.0.2     3758096386      udp
# 2             0.574101           2  128.238.147.255     2163119103      udp
# 3             3.096920           0        224.0.0.2     3758096386      udp
# 4             3.101557           1        224.0.0.2     3758096386      udp
#
#    is_tcp  is_udp
# 0       0       1
# 1       0       1
# 2       0       1
# 3       0       1
# 4       0       1

# %% [markdown]
# ## Combine TCP with UDP packets

# %%
# combine dataframes
pkt_feature_df = tcp_pkt_feature_df[['remote_ip2num','is_tcp','is_udp','pkt_len']].append(udp_pkt_feature_df[['remote_ip2num','is_tcp','is_udp','pkt_len']],ignore_index=True)

# %%
# shape
pkt_feature_df.shape
# Out:
# (96621, 4)

# %%
###### column types
pkt_feature_df.dtypes
# Out:
# remote_ip2num    int64
# is_tcp           int64
# is_udp           int64
# pkt_len          int64
# dtype: object

# %%
# describe
pkt_feature_df.describe()
# Out:
#        remote_ip2num        is_tcp        is_udp       pkt_len
# count   9.662100e+04  96621.000000  96621.000000  96621.000000
# mean    1.993104e+09      0.546486      0.453514    495.540100
# std     8.627334e+08      0.497837      0.497837    579.406738
# min     2.880297e+08      0.000000      0.000000      0.000000
# 25%     2.163119e+09      0.000000      0.000000     32.000000
# 50%     2.163119e+09      1.000000      0.000000    102.000000
# 75%     2.838481e+09      1.000000      1.000000   1368.000000
# max     4.026532e+09      1.000000      1.000000   1380.000000

# %%
# head 5 records
pkt_feature_df.head()
# Out:
#    remote_ip2num  is_tcp  is_udp  pkt_len
# 0      301500341       1       0     1368
# 1      301500341       1       0      101
# 2      301500341       1       0     1368
# 3     2163118960       1       0        0
# 4      301500341       1       0      824

# %%
# write to csv
pkt_feature_df.to_csv(TRACE_PACKET_FEATURE_FILE_NAME, index=False)
